# %%
import numpy as np
import pandas as pd
import collections

# %% [markdown]
# # ONT

# %%
ont_df = pd.read_csv('hprc_metadata_sample_files_ONT.tsv', sep='\t')

# %%
# Remove notes if all nan
if ont_df['notes'].isnull().all() == True:
    ont_df = ont_df.drop('notes', axis=1)

# %%
# TODO: Integrate with HPRC_metadata/merge_metadata.py combine_readstats.keep_columns
ont_meta_columns = ['filename',
        'sample_ID',
        'path',
        'filetype',
        'library_ID',
        'library_strategy',
        'library_source',
        'library_selection',
        'library_layout',
        'platform',
        'instrument_model',
        'design_description',
        'data_type',
        'shear_method',
        'size_selection',
        'seq_kit',
        'basecaller',
        'basecaller_version',
        'basecaller_model',
        'generator_facility',
        'generator_contact']

ont_readstat_columns = ['sample_ID', 
                        'filename',
                        'read_N50',
                        'Gb',
                        'coverage',
                        '100kb+',
                        '200kb+',
                        '300kb+',
                        '400kb+',
                        '500kb+',
                        '1Mb+',
                        'whales']

ont_df_nan_columns = ont_df.columns[ont_df.isna().any()].tolist()

# %%
ont_sample_missing_1_submitter_df = ont_df[ont_df.isnull().any(axis=1)]

# Number of ONT samples that have at least one missing submitter file missing
print(len(set(ont_df[ont_df['sample_ID'].isin(ont_sample_missing_1_submitter_df['sample_ID'].tolist())]['sample_ID'].tolist())))

# Export ONT sample files that have at least one missing submitter file missing
ont_df[ont_df['sample_ID'].isin(ont_sample_missing_1_submitter_df['sample_ID'].tolist())].reset_index(drop=True).to_csv('hprc_metadata_sample_files_missing_1_submitter_ONT.tsv', sep='\t')

for nan_column in ont_df_nan_columns:
    ont_df[nan_column] = ont_df[nan_column].ffill().tolist()
# Out:
# 14

# %%
ont_sample_meta_df = ont_df[ont_meta_columns].drop_duplicates(subset=['sample_ID'])
ont_sample_readstats_df = ont_df[ont_readstat_columns]

# %%
# Check no missing sample_ID for the sample meta and readstat subset
assert ont_df[~ont_df['sample_ID'].isin(ont_sample_meta_df['sample_ID'].tolist())].shape[0] == ont_df[~ont_df['sample_ID'].isin(ont_sample_readstats_df['sample_ID'].tolist())].shape[0] == 0

# %%
ont_sample_readstats_df = ont_sample_readstats_df.groupby('sample_ID').agg({'read_N50': 'mean',
                                                                          'coverage':'sum',
                                                                          '100kb+': 'sum',
                                                                          '200kb+': 'sum',
                                                                          '300kb+': 'sum',
                                                                          '400kb+': 'sum',
                                                                          '500kb+': 'sum',
                                                                          '1Mb+': 'sum',
                                                                          'whales': 'sum'}).reset_index()

# %%
ont_sample_df = pd.merge(ont_sample_meta_df, ont_sample_readstats_df, on='sample_ID')

# %%
assert len(set(ont_sample_df['sample_ID'].tolist())) == ont_sample_df.shape[0]

# %%
ont_sample_df.to_csv('hprc_metadata_sample_aggregate_ONT.tsv', sep='\t')

# %% [markdown]
# # HiFi

# %%
hifi_df = pd.read_csv('hprc_metadata_sample_files_HiFi.tsv', sep='\t')
hifi_df.head()
# Out:
#                         filename sample_ID  \
# 0  m54329U_200124_193652.ccs.bam   HG01891
# 1  m54329U_200127_180554.ccs.bam   HG01891
# 2  m54329U_200129_001928.ccs.bam   HG01891
# 3  m54329U_200130_064539.ccs.bam   HG01891
# 4  m54329U_200201_051510.ccs.bam   HG01123
#
#                                                 path    accession      study  \
# 0  s3://human-pangenomics/working/HPRC/HG01891/ra...  SRR13684280  SRP305758
# 1  s3://human-pangenomics/working/HPRC/HG01891/ra...  SRR13684280  SRP305758
# 2  s3://human-pangenomics/working/HPRC/HG01891/ra...  SRR13684280  SRP305758
# 3  s3://human-pangenomics/working/HPRC/HG01891/ra...  SRR13684280  SRP305758
# 4  s3://human-pangenomics/working/HPRC/HG01123/ra...  SRR13684290  SRP305758
#
#   biosample_accession  total_reads     total_bp  total_Gbp  min  ...  \
# 0        SAMN17861236      1596347  27122049640      27.12   47  ...
# 1        SAMN17861236      1755465  29883779569      29.88   46  ...
# 2        SAMN17861236      1779732  30200500419      30.20   45  ...
# 3        SAMN17861236      1636421  27919782706      27.92   46  ...
# 4        SAMN17861232      2072143  34554070679      34.55   46  ...
#
#                           design_description        data_type  shear_method  \
# 0  HiFi sequencing of 18kb fractionated gDNA  unaligned reads        g-TUBE
# 1  HiFi sequencing of 18kb fractionated gDNA  unaligned reads        g-TUBE
# 2  HiFi sequencing of 18kb fractionated gDNA  unaligned reads        g-TUBE
# 3  HiFi sequencing of 18kb fractionated gDNA  unaligned reads        g-TUBE
# 4  HiFi sequencing of 17kb fractionated gDNA  unaligned reads        g-TUBE
#
#    size_selection                        ccs_algorithm  polymerase_version  \
# 0         SageELF  ccs 4.0.0 (commit SL-release-8.0.0)                P2.0
# 1         SageELF  ccs 4.0.0 (commit SL-release-8.0.0)                P2.0
# 2         SageELF  ccs 4.0.0 (commit SL-release-8.0.0)                P2.0
# 3         SageELF  ccs 4.0.0 (commit SL-release-8.0.0)                P2.0
# 4         SageELF  ccs 4.0.0 (commit SL-release-8.0.0)                P2.0
#
#    seq_plate_chemistry_version        generator_facility generator_contact  \
# 0                         C2.0  University of Washington   kmiyamot@uw.edu
# 1                         C2.0  University of Washington   kmiyamot@uw.edu
# 2                         C2.0  University of Washington   kmiyamot@uw.edu
# 3                         C2.0  University of Washington   kmiyamot@uw.edu
# 4                         C2.0  University of Washington   kmiyamot@uw.edu
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 35 columns]

# %%
# Remove notes if all nan
if hifi_df['notes'].isnull().all() == True:
    hifi_df = hifi_df.drop('notes', axis=1)

# %%
required_hifi_1_submitter_columns = ['sample_ID', 'filename', 'library_ID', 'library_strategy', 'library_source', 'library_selection', 'library_layout', 'platform', 'instrument_model', 
                    'design_description', 'data_type', 'shear_method', 'size_selection', 'ccs_algorithm', 'polymerase_version', 'seq_plate_chemistry_version', 
                    'generator_facility', 'generator_contact', 'notes']

required_hifi_5_readstats_columns = ['sample_ID','filename', 'total_reads', 'total_bp', 'total_Gbp', 'min', 'max', 'mean', 'quartile_25', 'quartile_50', 'quartile_75', 'N25', 'N50', 'N75']

# %%
require_hifi_1_submitter_dict = {sample: {key: None for key in required_hifi_1_submitter_columns} for sample in hifi_df['sample_ID'].tolist()} 
for sample in list(set(hifi_df['sample_ID'].tolist())):
    # print(sample, required_hifi_1_submitter_columns)
    
    sample_array = hifi_df[hifi_df['sample_ID'].isin([sample])][required_hifi_1_submitter_columns].values
    
    # print(sample)
    # print(sample_array)
    # print(len(required_hifi_1_submitter_columns))
    
    assert len(required_hifi_1_submitter_columns) == sample_array.shape[1]
    
    for column_index in range(sample_array.shape[1]):
        # print(sample_array[0, column_index], sample_array[:, column_index])
        if np.all(sample_array[:, column_index] == sample_array[0, column_index]):
            # print(sample_array[0, column_index], 
            #       required_hifi_1_submitter_columns[column_index], 
            #       sample_array[:, column_index].tolist()[0])
            # print('\n')
            require_hifi_1_submitter_dict[sample][required_hifi_1_submitter_columns[column_index]] = sample_array[0, column_index]
        else:
            # print(sample_array[0, column_index])
            require_hifi_1_submitter_dict[sample][required_hifi_1_submitter_columns[column_index]] = sample_array[:, column_index]
            # print(required_hifi_1_submitter_columns[column_index],
                  # sample_array[:, column_index])
            # print('\n')
            # pass

# %%
# contains_none = any(value is None or (isinstance(value, list) and None in value) for value in require_hifi_1_submitter_dict.values())
# contains_nan = any(value == 'nan' or (isinstance(value, list) and 'nan' in value) for value in require_hifi_1_submitter_dict.values())

# %%
type(require_hifi_1_submitter_dict['HG01891']['filename'])
# Out:
# numpy.ndarray

# %%
require_hifi_1_submitter_dict['HG02717']
# Out:
# {'sample_ID': 'HG02717',
#  'filename': array(['m64043_200403_163826.ccs.bam', 'm64043_200405_180950.ccs.bam',
#         'm64043_200407_002219.ccs.bam', 'm64043_200408_064651.ccs.bam'],
#        dtype=object),
#  'library_ID': 'HG02717_lib1',
#  'library_strategy': 'WGS',
#  'library_source': 'GENOMIC',
#  'library_selection': 'size fractionation',
#  'library_layout': 'single',
#  'platform': 'PACBIO_SMRT',
#  'instrument_model': 'PacBio Sequel II',
#  'design_description': 'HiFi sequencing of 20kb fractionated gDNA',
#  'data_type': 'unaligned reads',
#  'shear_method': 'Megaruptor 1',
#  'size_selection': 'SageELF',
#  'ccs_algorithm': '8.0.0.80529',
#  'polymerase_version': array([nan, nan, nan, nan], dtype=object),
#  'seq_plate_chemistry_version': array([nan, nan, nan, nan], dtype=object),
#  'generator_facility': 'Washington University',
#  'generator_contact': 'tgraves@wustl.edu',
#  'notes': array([nan, nan, nan, nan], dtype=object)}

# %%
samples_missing_submmiter_1_hifi = []
for sample_id, meta_dict in require_hifi_1_submitter_dict.items():
    # print(sample_id, meta_dict)
    for key, value in meta_dict.items():
        if isinstance(value, np.ndarray):
            if any(item == 'nan' or pd.isna(item) for item in value):
                if key == 'notes':
                    pass
                else:
                    samples_missing_submmiter_1_hifi.append(sample_id)

# %%
hifi_1_submitter_df = pd.DataFrame.from_dict(require_hifi_1_submitter_dict, orient='index')

# %%
hifi_1_submitter_df[hifi_1_submitter_df['sample_ID'].isin(samples_missing_submmiter_1_hifi)].to_csv('hprc_metadata_sample_files_missing_1_submitter_HiFi.tsv', sep='\t')

# %%
# # Retired
# hifi_sample_meta_df = hifi_df[required_hifi_1_submitter_columns].drop_duplicates(subset=['sample_ID']).reset_index(drop=True)
# hifi_sample_missing_1_submitter_list = []
# for sample in hifi_sample_meta_df['sample_ID'].tolist():
#     if sum(hifi_sample_meta_df[hifi_sample_meta_df['sample_ID'].isin([sample])].isna().any()) == 0:
#         pass
#     else:
#         hifi_sample_missing_1_submitter_df = hifi_sample_meta_df[hifi_sample_meta_df['sample_ID'].isin([sample])]
#         if hifi_sample_missing_1_submitter_df.columns[hifi_sample_missing_1_submitter_df.isna().any()].tolist() == ['notes']:
#             pass
#         else:
#             # print(sample, hifi_sample_missing_1_submitter_df.columns[hifi_sample_missing_1_submitter_df.isna().any()].tolist())
#             hifi_sample_missing_1_submitter_list.append(sample)
# print(len(hifi_sample_missing_1_submitter_list))

# hifi_sample_meta_df[hifi_sample_meta_df['sample_ID'].isin(hifi_sample_missing_1_submitter_list)].reset_index().to_csv('hprc_metadata_sample_files_missing_1_submitter_HiFi.tsv', sep='\t')

# %%
hifi_sample_readstats_df = hifi_df[required_hifi_5_readstats_columns]
hifi_sample_readstats_df = hifi_sample_readstats_df.groupby('sample_ID').agg({'total_reads': 'sum',
                                                   'total_bp': 'sum',
                                                   'total_Gbp': 'sum',
                                                   'min': 'mean',
                                                   'max': 'mean',
                                                   'quartile_25': 'mean',
                                                   'quartile_50': 'mean',
                                                   'quartile_75': 'mean',
                                                   'N25': 'mean',
                                                   'N50': 'mean', # assembly term shortest contig of the total assembly length (different for ONT)
                                                   'N75': 'mean'}).reset_index()

# %%
hifi_sample_df = pd.merge(hifi_1_submitter_df, hifi_sample_readstats_df, on='sample_ID')

# %%
# Check that sample's with missing 1_submitter metadata are present
assert hifi_sample_df[hifi_sample_df['sample_ID'].isin(samples_missing_submmiter_1_hifi)].shape[0] == len(set(samples_missing_submmiter_1_hifi))

# %%
hifi_sample_df.to_csv('hprc_metadata_sample_aggregate_HiFi.tsv', sep='\t')

# %%
hifi_sample_df.head()
# Out:
#   sample_ID                                           filename  \
# 0   HG01891  [m54329U_200124_193652.ccs.bam, m54329U_200127...
# 1   HG01123  [m54329U_200201_051510.ccs.bam, m54329U_200203...
# 2   HG02559  [m54329U_200211_192235.ccs.bam, m54329U_200217...
# 3   HG02486  [m54329U_200215_021808.ccs.bam, m54329U_200313...
# 4   HG01361  [m54329U_200306_185930.ccs.bam, m54329U_200308...
#
#                                           library_ID library_strategy  \
# 0                                  HG01891.HiFiEx_f2              WGS
# 1                                  HG01123_HiFiEx_f2              WGS
# 2  [HG02559.HiFiEx_b6, HG02559.HiFiEx_f2, HG02559...              WGS
# 3  [HG02486.HiFiEx_f2, HG02486.HiFiEx2_f2, HG0248...              WGS
# 4  [HG01361.HiFiEx_f2, HG01361.HiFiEx_f2, HG01361...              WGS
#
#   library_source   library_selection library_layout     platform  \
# 0        GENOMIC  size fractionation         single  PACBIO_SMRT
# 1        GENOMIC  size fractionation         single  PACBIO_SMRT
# 2        GENOMIC  size fractionation         single  PACBIO_SMRT
# 3        GENOMIC  size fractionation         single  PACBIO_SMRT
# 4        GENOMIC  size fractionation         single  PACBIO_SMRT
#
#    instrument_model                                 design_description  ...  \
# 0  PacBio Sequel II          HiFi sequencing of 18kb fractionated gDNA  ...
# 1  PacBio Sequel II          HiFi sequencing of 17kb fractionated gDNA  ...
# 2  PacBio Sequel II          HiFi sequencing of 20kb fractionated gDNA  ...
# 3  PacBio Sequel II  [HiFi sequencing of 22kb fractionated gDNA, Hi...  ...
# 4  PacBio Sequel II  [HiFi sequencing of 20kb fractionated gDNA, Hi...  ...
#
#        total_bp total_Gbp   min       max quartile_25 quartile_50  \
# 0  115126112334    115.12  46.0  44384.75    15781.75    16865.00
# 1  119417336179    119.40  46.0  43082.25    14998.75    16470.25
# 2  128540762559    128.54  46.2  47600.40    18524.80    19951.20
# 3  123904875583    123.92  46.5  45554.50    17439.50    18733.00
# 4  129995062425    129.99  46.2  48381.20    18101.60    19655.20
#
#     quartile_75       N25      N50           N75
# 0  18096.000000  15930.00  17039.5  18287.750000
# 1  18144.000000  15302.25  16815.5  18543.000000
# 2  21644.200000  18764.80  20247.0  22029.400000
# 3  20268.833333  17658.50  19000.0  20602.333333
# 4  21501.200000  18408.20  20016.2  21955.600000
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Check: Methylation Header in BAM
#
# Example commands
# ```bash
# samtools view s3://human-pangenomics/working/HPRC/HG03704/raw_data/PacBio_HiFi/m54329U_211105_213234-bc1001.5mc.hifi_reads.bam \
# 	| head -n 1 | grep "MM:Z:C+m"
#  ```
#
#
# A couple keys here:
#
# * Identifying full s3 paths to the files you are trying to check, you sometimes have to built that path back after an aws s3 ls
#
# * Leverage samtools ability to view a file directly in s3.  I had to downgrade to samtools 1.18 for it to work for me.
#
# * Use the -H flag on samtools view to limit view to just the header, or it will print the whole file!
#
# * Figure out what in the header indicates if methylation tags are present in the file, knowing that primrose is not the current methylation caller anymore, i don't think. you may have to check for the actual tags in the bam, per this: https://www.genomeark.org/documentation/hifi-reads-bam-tags.html

# %%
hifi_sample_df.head()
# Out:
#   sample_ID                                           filename  \
# 0   HG01891  [m54329U_200124_193652.ccs.bam, m54329U_200127...
# 1   HG01123  [m54329U_200201_051510.ccs.bam, m54329U_200203...
# 2   HG02559  [m54329U_200211_192235.ccs.bam, m54329U_200217...
# 3   HG02486  [m54329U_200215_021808.ccs.bam, m54329U_200313...
# 4   HG01361  [m54329U_200306_185930.ccs.bam, m54329U_200308...
#
#                                           library_ID library_strategy  \
# 0                                  HG01891.HiFiEx_f2              WGS
# 1                                  HG01123_HiFiEx_f2              WGS
# 2  [HG02559.HiFiEx_b6, HG02559.HiFiEx_f2, HG02559...              WGS
# 3  [HG02486.HiFiEx_f2, HG02486.HiFiEx2_f2, HG0248...              WGS
# 4  [HG01361.HiFiEx_f2, HG01361.HiFiEx_f2, HG01361...              WGS
#
#   library_source   library_selection library_layout     platform  \
# 0        GENOMIC  size fractionation         single  PACBIO_SMRT
# 1        GENOMIC  size fractionation         single  PACBIO_SMRT
# 2        GENOMIC  size fractionation         single  PACBIO_SMRT
# 3        GENOMIC  size fractionation         single  PACBIO_SMRT
# 4        GENOMIC  size fractionation         single  PACBIO_SMRT
#
#    instrument_model                                 design_description  ...  \
# 0  PacBio Sequel II          HiFi sequencing of 18kb fractionated gDNA  ...
# 1  PacBio Sequel II          HiFi sequencing of 17kb fractionated gDNA  ...
# 2  PacBio Sequel II          HiFi sequencing of 20kb fractionated gDNA  ...
# 3  PacBio Sequel II  [HiFi sequencing of 22kb fractionated gDNA, Hi...  ...
# 4  PacBio Sequel II  [HiFi sequencing of 20kb fractionated gDNA, Hi...  ...
#
#        total_bp total_Gbp   min       max quartile_25 quartile_50  \
# 0  115126112334    115.12  46.0  44384.75    15781.75    16865.00
# 1  119417336179    119.40  46.0  43082.25    14998.75    16470.25
# 2  128540762559    128.54  46.2  47600.40    18524.80    19951.20
# 3  123904875583    123.92  46.5  45554.50    17439.50    18733.00
# 4  129995062425    129.99  46.2  48381.20    18101.60    19655.20
#
#     quartile_75       N25      N50           N75
# 0  18096.000000  15930.00  17039.5  18287.750000
# 1  18144.000000  15302.25  16815.5  18543.000000
# 2  21644.200000  18764.80  20247.0  22029.400000
# 3  20268.833333  17658.50  19000.0  20602.333333
# 4  21501.200000  18408.20  20016.2  21955.600000
#
# [5 rows x 30 columns]

# %%
s3_df = pd.read_csv('s3-bucket.tsv', sep='\t', index_col=[0])

# %%
s3_dict = {data[0]:data[1] for data in s3_df.values}

# %%
list(set(hifi_sample_df['sample_ID'].tolist()))[0]
# Out:
# 'HG01106'

# %%
len(set(hifi_sample_df['sample_ID'].tolist()))
# Out:
# 122

# %%
hifi_sample_df[required_hifi_1_submitter_columns]
# Out:
#     sample_ID                                           filename  \
# 0     HG01891  [m54329U_200124_193652.ccs.bam, m54329U_200127...
# 1     HG01123  [m54329U_200201_051510.ccs.bam, m54329U_200203...
# 2     HG02559  [m54329U_200211_192235.ccs.bam, m54329U_200217...
# 3     HG02486  [m54329U_200215_021808.ccs.bam, m54329U_200313...
# 4     HG01361  [m54329U_200306_185930.ccs.bam, m54329U_200308...
# ..        ...                                                ...
# 117   HG01934  [m64136_210723_184622.hifi_reads.bam, m64136_2...
# 118   HG00408  [m64136_211111_194404-bc1002.5mc.hifi_reads.ba...
# 119   HG02129  [m64136_220422_181133-bc1001.5mc.hifi_reads.ba...
# 120   NA20805  [m64136_220726_203708-bc1020.5mc.hifi_reads.ba...
# 121   NA20752  [m64457e_220827_152226-bc2052.5mc.hifi_reads.b...
#
#                                             library_ID library_strategy  \
# 0                                    HG01891.HiFiEx_f2              WGS
# 1                                    HG01123_HiFiEx_f2              WGS
# 2    [HG02559.HiFiEx_b6, HG02559.HiFiEx_f2, HG02559...              WGS
# 3    [HG02486.HiFiEx_f2, HG02486.HiFiEx2_f2, HG0248...              WGS
# 4    [HG01361.HiFiEx_f2, HG01361.HiFiEx_f2, HG01361...              WGS
# ..                                                 ...              ...
# 117                                       HG01934_lib1              WGS
# 118                                       HG00408_lib1              WGS
# 119                                       HG02129_lib1              WGS
# 120                                       NA20805_lib1              WGS
# 121                                       PG20752.HFSS              WGS
#
#     library_source   library_selection library_layout     platform  \
# 0          GENOMIC  size fractionation         single  PACBIO_SMRT
# 1          GENOMIC  size fractionation         single  PACBIO_SMRT
# 2          GENOMIC  size fractionation         single  PACBIO_SMRT
# 3          GENOMIC  size fractionation         single  PACBIO_SMRT
# 4          GENOMIC  size fractionation         single  PACBIO_SMRT
# ..             ...                 ...            ...          ...
# 117        GENOMIC  size fractionation         single  PACBIO_SMRT
# 118        GENOMIC  size fractionation         single  PACBIO_SMRT
# 119        GENOMIC  size fractionation         single  PACBIO_SMRT
# 120        GENOMIC  size fractionation         single  PACBIO_SMRT
# 121        GENOMIC              RANDOM         single  PACBIO_SMRT
#
#      instrument_model                                 design_description  \
# 0    PacBio Sequel II          HiFi sequencing of 18kb fractionated gDNA
# 1    PacBio Sequel II          HiFi sequencing of 17kb fractionated gDNA
# 2    PacBio Sequel II          HiFi sequencing of 20kb fractionated gDNA
# 3    PacBio Sequel II  [HiFi sequencing of 22kb fractionated gDNA, Hi...
# 4    PacBio Sequel II  [HiFi sequencing of 20kb fractionated gDNA, Hi...
# ..                ...                                                ...
# 117  PacBio Sequel II          HiFi sequencing of 20kb fractionated gDNA
# 118  PacBio Sequel II          HiFi sequencing of 20kb fractionated gDNA
# 119  PacBio Sequel II          HiFi sequencing of 20kb fractionated gDNA
# 120  PacBio Sequel II          HiFi sequencing of 20kb fractionated gDNA
# 121  PacBio Sequel II          HiFi sequencing of 23kb fractionated gDNA
#
#            data_type  shear_method size_selection  \
# 0    unaligned reads        g-TUBE        SageELF
# 1    unaligned reads        g-TUBE        SageELF
# 2    unaligned reads        g-TUBE        SageELF
# 3    unaligned reads        g-TUBE        SageELF
# 4    unaligned reads        g-TUBE        SageELF
# ..               ...           ...            ...
# 117  unaligned reads  Megaruptor 1        SageELF
# 118  unaligned reads  Megaruptor 1        SageELF
# 119  unaligned reads  Megaruptor 1        SageELF
# 120  unaligned reads  Megaruptor 1        SageELF
# 121  unaligned reads  Megaruptor 3       PippinHT
#
#                            ccs_algorithm polymerase_version  \
# 0    ccs 4.0.0 (commit SL-release-8.0.0)               P2.0
# 1    ccs 4.0.0 (commit SL-release-8.0.0)               P2.0
# 2    ccs 4.0.0 (commit SL-release-8.0.0)               P2.0
# 3    ccs 4.0.0 (commit SL-release-8.0.0)               P2.0
# 4    ccs 4.0.0 (commit SL-release-8.0.0)               P2.0
# ..                                   ...                ...
# 117                        10.1.0.115913                 P2
# 118                                6.0.0               P2.2
# 119                                6.0.0               P2.2
# 120                                6.0.0               P2.2
# 121                                6.3.0               P3.2
#
#     seq_plate_chemistry_version        generator_facility  generator_contact  \
# 0                          C2.0  University of Washington    kmiyamot@uw.edu
# 1                          C2.0  University of Washington    kmiyamot@uw.edu
# 2                          C2.0  University of Washington    kmiyamot@uw.edu
# 3                          C2.0  University of Washington    kmiyamot@uw.edu
# 4                          C2.0  University of Washington    kmiyamot@uw.edu
# ..                          ...                       ...                ...
# 117                          C2     Washington University  tgraves@wustl.edu
# 118                          C2     Washington University  tgraves@wustl.edu
# 119                          C2     Washington University  tgraves@wustl.edu
# 120                          C2     Washington University  tgraves@wustl.edu
# 121                          C2  University of Washington    kmiyamot@uw.edu
#
#                                                  notes
# 0                                 [nan, nan, nan, nan]
# 1                                 [nan, nan, nan, nan]
# 2                            [nan, nan, nan, nan, nan]
# 3    [nan, second library prep, second library prep...
# 4                            [nan, nan, nan, nan, nan]
# ..                                                 ...
# 117                            bc1020 barcoded adapter
# 118                                    [nan, nan, nan]
# 119                                    [nan, nan, nan]
# 120                                    [nan, nan, nan]
# 121                                    [nan, nan, nan]
#
# [122 rows x 19 columns]

# %%
hifi_sample_df[hifi_sample_df['sample_ID'].isin(['HG03704'])]['filename'].tolist()[0][0]
# Out:
# 'm54329U_211105_213234-bc1001.5mc.hifi_reads.bam'

# %%
s3_dict[hifi_sample_df[hifi_sample_df['sample_ID'].isin(['HG03704'])]['filename'].tolist()[0][0]]
# Out:
# 's3://human-pangenomics/working/HPRC/HG03704/raw_data/PacBio_HiFi/m54329U_211105_213234-bc1001.5mc.hifi_reads.bam'

# %%
bam_list = []
for sample_data in hifi_sample_df[['sample_ID', 'filename']].values:
    print(sample_data[0])
    bam_list.append(len(sample_data[1]))
    for file in sample_data[1]:
        print(

        # -H $i 2>/dev/null | grep -q primrose
        # sam_cmd_1 = '/private/home/iviolich/tools/samtools-1.18/samtools view ' + s3_dict[file] + ' | head -n 1 | grep "MM:Z:C+m"'
        
        sam_cmd_1 = '/private/home/iviolich/tools/samtools-1.18/samtools view -H ' + s3_dict[file] + " | head -n 10 | grep 'MM:Z:C+m' | wc -l"  # update toe boolean
        sam_cmd_2 = '/private/home/iviolich/tools/samtools-1.18/samtools view -H ' + s3_dict[file] + " | grep 'primrose' | wc -l"
        # boolean
        # check 50

        # print(sam_cmd_1)
        print(sam_cmd_2)
    print('\n')

print(sum(bam_list))

# samtools view some_file.bam | head -n 1 | tr '\t' '\n' | less -S
# Out:
# HG01891
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG01891/raw_data/PacBio_HiFi/m54329U_200124_193652.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG01891/raw_data/PacBio_HiFi/m54329U_200127_180554.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG01891/raw_data/PacBio_HiFi/m54329U_200129_001928.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG01891/raw_data/PacBio_HiFi/m54329U_200130_064539.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
#
#
# HG01123
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG01123/raw_data/PacBio_HiFi/m54329U_200201_051510.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG01123/raw_data/PacBio_HiFi/m54329U_200203_181235.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG01123/raw_data/PacBio_HiFi/m54329U_200205_002609.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG01123/raw_data/PacBio_HiFi/m54329U_200206_215926.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
#
#
# HG02559
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02559/raw_data/PacBio_HiFi/m54329U_200211_192235.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02559/raw_data/PacBio_HiFi/m54329U_200217_055345.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02559/raw_data/PacBio_HiFi/m54329U_200219_181523.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02559/raw_data/PacBio_HiFi/m64076_200215_021919.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02559/raw_data/PacBio_HiFi/m64076_200217_055339.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
#
#
# HG02486
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02486/raw_data/PacBio_HiFi/m54329U_200215_021808.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02486/raw_data/PacBio_HiFi/m54329U_200313_161638.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02486/raw_data/PacBio_HiFi/m54329U_200315_215927.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02486/raw_data/PacBio_HiFi/m54329U_200317_041347.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02486/raw_data/PacBio_HiFi/m54329U_200320_213710.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02486/raw_data/PacBio_HiFi/m64076_200211_192227.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
#
#
# HG01361
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG01361/raw_data/PacBio_HiFi_Swap_Fixed/m54329U_200306_185930.ccs.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/H
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02129/raw_data/PacBio_HiFi/m64136_220422_181133-bc1001.5mc.hifi_reads.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02129/raw_data/PacBio_HiFi/m64136_220424_050632-bc1001.5mc.hifi_reads.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/HG02129/raw_data/PacBio_HiFi/m64136_220426_155627-bc1001.5mc.hifi_reads.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
#
#
# NA20805
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/NA20805/raw_data/PacBio_HiFi/m64136_220726_203708-bc1020.5mc.hifi_reads.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/NA20805/raw_data/PacBio_HiFi/m64136_220728_160902-bc1020.5mc.hifi_reads.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/NA20805/raw_data/PacBio_HiFi/m64136_220730_113921-bc1020.5mc.hifi_reads.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
#
#
# NA20752
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/NA20752/raw_data/PacBio_HiFi/m64457e_220827_152226-bc2052.5mc.hifi_reads.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/NA20752/raw_data/PacBio_HiFi/m64457e_220829_104034-bc2052.5mc.hifi_reads.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
# /private/home/iviolich/tools/samtools-1.18/samtools view s3://human-pangenomics/working/HPRC/NA20752/raw_data/PacBio_HiFi/m64457e_220831_195843-bc2052.5mc.hifi_reads.bam | head -n 10 | tr '\t' '\n' | less -S | grep 'MM:Z:C+m' | wc -l
#
#
# 465

# %% [markdown]
# # Deep Consensus

# %%
dc_df = pd.read_csv('hprc_metadata_sample_files_DEEPCONSENSUS.tsv', sep='\t')
dc_df.head()
# Out:
#                                         filename sample_ID  \
# 0  HG00099.m54329U_220825_174247.dc.q20.fastq.gz   HG00099
# 1  HG00099.m54329U_220827_143814.dc.q20.fastq.gz   HG00099
# 2  HG00099.m54329U_220829_095708.dc.q20.fastq.gz   HG00099
# 3   HG00140.m64043_220728_173215.dc.q20.fastq.gz   HG00140
# 4   HG00140.m64136_220715_182717.dc.q20.fastq.gz   HG00140
#
#                                                 path    accession      study  \
# 0  s3://human-pangenomics/working/HPRC/HG00099/ra...  SRR26545347  SRP305758
# 1  s3://human-pangenomics/working/HPRC/HG00099/ra...  SRR26545347  SRP305758
# 2  s3://human-pangenomics/working/HPRC/HG00099/ra...  SRR26545347  SRP305758
# 3  s3://human-pangenomics/working/HPRC/HG00140/ra...  SRR26545346  SRP305758
# 4  s3://human-pangenomics/working/HPRC/HG00140/ra...  SRR26545346  SRP305758
#
#   biosample_accession  total_reads     total_bp  total_Gbp  min  ...  \
# 0        SAMN33758778      2687625  56102007798      56.10  107  ...
# 1        SAMN33758778      2643186  52918724515      52.92  345  ...
# 2        SAMN33758778      2866917  57539149577      57.54  138  ...
# 3        SAMN33621941       572695  11345594738      11.35  117  ...
# 4        SAMN33621941      1674999  36918329655      36.92  400  ...
#
#                                   design_description        data_type  \
# 0  HiFi sequencing of 20kb fractionated gDNA reba...  unaligned reads
# 1  HiFi sequencing of 20kb fractionated gDNA reba...  unaligned reads
# 2  HiFi sequencing of 20kb fractionated gDNA reba...  unaligned reads
# 3  HiFi sequencing of 20kb fractionated gDNA reba...  unaligned reads
# 4  HiFi sequencing of 20kb fractionated gDNA reba...  unaligned reads
#
#    shear_method  size_selection  DeepConsensus_version  polymerase_version  \
# 0  Megaruptor 3        PippinHT                    1.2                  P2
# 1  Megaruptor 3        PippinHT                    1.2                  P2
# 2  Megaruptor 3        PippinHT                    1.2                  P2
# 3  Megaruptor 3        PippinHT                    1.2                  P2
# 4  Megaruptor 3        PippinHT                    1.2                  P2
#
#    seq_plate_chemistry_version        generator_facility generator_contact  \
# 0                           C2  University of Washington   kmiyamot@uw.edu
# 1                           C2  University of Washington   kmiyamot@uw.edu
# 2                           C2  University of Washington   kmiyamot@uw.edu
# 3                           C2  University of Washington   kmiyamot@uw.edu
# 4                           C2  University of Washington   kmiyamot@uw.edu
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 35 columns]

# %%
# Remove notes if all nan
if dc_df['notes'].isnull().all() == True:
    dc_df = dc_df.drop('notes', axis=1)

# %%
required_deepconsensus_submitter_columns = ['filename', 'sample_ID', 'library_ID', 'library_strategy', 'library_source', 
                                            'library_selection', 'library_layout', 'platform', 'instrument_model', 'design_description', 
                                            'data_type', 'shear_method', 'size_selection', 
                                            'DeepConsensus_version', 'polymerase_version', 
                                            'seq_plate_chemistry_version', 'generator_facility', 
                                            'generator_contact']

required_deepconsensus_readstats_columns = ['sample_ID', 'filename', 'total_reads', 'total_bp', 'total_Gbp', 'min', 'max', 'mean', 'quartile_25', 'quartile_50', 'quartile_75', 'N25', 'N50', 'N75']

# %%
dc_sample_meta_df = dc_df[required_deepconsensus_submitter_columns].drop_duplicates(subset=['sample_ID']).reset_index(drop=True)

# %%
# dc_sample_meta_df

# %%
dc_sample_missing_1_submitter_list = []
for sample in dc_sample_meta_df['sample_ID'].tolist():
    if sum(dc_sample_meta_df[dc_sample_meta_df['sample_ID'].isin([sample])].isna().any()) == 0:
        pass
    else:
        dc_sample_missing_1_submitter_df = dc_sample_meta_df[dc_sample_meta_df['sample_ID'].isin([sample])]
        if dc_sample_missing_1_submitter_df.columns[dc_sample_missing_1_submitter_df.isna().any()].tolist() == ['notes']:
            pass
        else:
            # print(sample, hifi_sample_missing_1_submitter_df.columns[hifi_sample_missing_1_submitter_df.isna().any()].tolist())
            dc_sample_missing_1_submitter_list.append(sample)
print(len(dc_sample_missing_1_submitter_list))
# Out:
# 0

# %%
# Check all dc sample 5_readstats data is present
assert sum(dc_df[required_deepconsensus_readstats_columns].isna().any()) == 0

# %%
dc_sample_readstats_df = dc_df[required_deepconsensus_readstats_columns]

dc_sample_readstats_df = dc_sample_readstats_df.groupby('sample_ID').agg({'total_reads': 'sum',
                                               'total_bp': 'sum',
                                               'total_Gbp': 'sum',
                                               'min': 'mean',
                                               'max': 'mean',
                                               'quartile_25': 'mean',
                                               'quartile_50': 'mean',
                                               'quartile_75': 'mean',
                                               'N25': 'mean',
                                               'N50': 'mean',
                                               'N75': 'mean'}).reset_index()

# %%
dc_sample_df = pd.merge(dc_sample_meta_df, dc_sample_readstats_df, on='sample_ID')

# %%
dc_sample_df.to_csv('hprc_metadata_sample_aggregate_DEEPCONSENSUS.tsv', sep='\t')

# %%
dc_sample_df.head() # finished table with no non-unique
# filename, library_ID
# Out:
#                                         filename sample_ID         library_ID  \
# 0  HG00099.m54329U_220825_174247.dc.q20.fastq.gz   HG00099  PG00099_1.HFSS_dc
# 1   HG00140.m64043_220728_173215.dc.q20.fastq.gz   HG00140    HG00140_lib1_dc
# 2  HG00280.m54329U_220901_221341.dc.q20.fastq.gz   HG00280    PG00280.HFSS_dc
# 3   HG00323.m64043_220728_173215.dc.q20.fastq.gz   HG00323    HG00323_lib1_dc
# 4   HG00408.m64136_211111_194404.dc.q20.fastq.gz   HG00408    HG00408_lib1_dc
#
#   library_strategy library_source   library_selection library_layout  \
# 0              WGS        GENOMIC  size fractionation         single
# 1              WGS        GENOMIC  size fractionation         single
# 2              WGS        GENOMIC  size fractionation         single
# 3              WGS        GENOMIC  size fractionation         single
# 4              WGS        GENOMIC  size fractionation         single
#
#       platform  instrument_model  \
# 0  PACBIO_SMRT  PacBio Sequel II
# 1  PACBIO_SMRT  PacBio Sequel II
# 2  PACBIO_SMRT  PacBio Sequel II
# 3  PACBIO_SMRT  PacBio Sequel II
# 4  PACBIO_SMRT  PacBio Sequel II
#
#                                   design_description  ...      total_bp  \
# 0  HiFi sequencing of 20kb fractionated gDNA reba...  ...  166559881890
# 1  HiFi sequencing of 20kb fractionated gDNA reba...  ...  126611334877
# 2  HiFi sequencing of 20kb fractionated gDNA reba...  ...  151564344052
# 3  HiFi sequencing of 20kb fractionated gDNA reba...  ...  120027730827
# 4  HiFi sequencing of 20kb fractionated gDNA reba...  ...  134450022475
#
#   total_Gbp         min           max   quartile_25   quartile_50  \
# 0    166.56  196.666667  62248.666667  17449.333333  19636.333333
# 1    126.62  272.500000  67774.500000  18393.250000  20448.500000
# 2    151.56   95.000000  64738.666667  17189.666667  19452.666667
# 3    120.03  368.750000  60432.750000  16941.500000  19105.500000
# 4    134.45  396.666667  63712.666667  16502.333333  17981.000000
#
#     quartile_75           N25           N50           N75
# 0  22651.666667  17950.333333  20409.333333  23637.666667
# 1  23623.250000  18873.500000  21263.000000  24996.250000
# 2  22546.000000  17712.333333  20266.666667  23568.000000
# 3  21983.250000  17417.000000  19893.750000  22834.500000
# 4  21025.666667  16795.666667  18577.333333  22431.333333
#
# [5 rows x 29 columns]

# %% [markdown]
# # Sample Aggregate

# %%
merge_samples = set(dc_sample_df['sample_ID'].tolist()).union(hifi_sample_df['sample_ID'].tolist(), ont_sample_df['sample_ID'].tolist())

# %%
ont_sample_df.head()
# Out:
#                                             filename sample_ID  \
# 0  02_08_22_R941_HG00558_1_Guppy_6.5.7_450bps_mod...   HG00558
# 1  02_08_22_R941_HG01252_1_Guppy_6.5.7_450bps_mod...   HG01252
# 2  02_08_22_R941_HG02258_1_Guppy_6.5.7_450bps_mod...   HG02258
# 3  02_08_22_R941_HG03834_1_Guppy_6.5.7_450bps_mod...   HG03834
# 4  02_15_22_R941_HG00658_1_Guppy_6.5.7_450bps_mod...   HG00658
#
#                                                 path filetype  \
# 0  s3://human-pangenomics/working/HPRC/HG00558/ra...      bam
# 1  s3://human-pangenomics/working/HPRC/HG01252/ra...      bam
# 2  s3://human-pangenomics/working/HPRC/HG02258/ra...      bam
# 3  s3://human-pangenomics/working/HPRC/HG03834/ra...      bam
# 4  s3://human-pangenomics/working/HPRC/HG00658/ra...      bam
#
#                 library_ID library_strategy library_source library_selection  \
# 0  02_08_22_R941_HG00558_1              WGS        GENOMIC            RANDOM
# 1  02_08_22_R941_HG01252_1              WGS        GENOMIC            RANDOM
# 2  02_08_22_R941_HG02258_1              WGS        GENOMIC            RANDOM
# 3  02_08_22_R941_HG03834_1              WGS        GENOMIC            RANDOM
# 4  02_15_22_R941_HG00658_1              WGS        GENOMIC            RANDOM
#
#   library_layout         platform  ...  generator_contact       read_N50  \
# 0         single  OXFORD_NANOPORE  ...  iviolich@ucsc.edu   98073.000000
# 1         single  OXFORD_NANOPORE  ...  iviolich@ucsc.edu   79697.666667
# 2         single  OXFORD_NANOPORE  ...  iviolich@ucsc.edu   98838.500000
# 3         single  OXFORD_NANOPORE  ...  iviolich@ucsc.edu  107647.333333
# 4         single  OXFORD_NANOPORE  ...  iviolich@ucsc.edu   90313.333333
#
#   coverage 100kb+ 200kb+ 300kb+ 400kb+ 500kb+  1Mb+ whales
# 0    54.43  26.69   7.30   1.60   0.45   0.18  0.00     35
# 1    47.53  17.45   3.02   0.66   0.18   0.07  0.00      7
# 2    49.73  25.01   6.62   1.26   0.26   0.08  0.00      5
# 3    48.80  26.33   8.97   3.23   1.35   0.64  0.03     99
# 4    68.25  30.80   8.37   1.85   0.49   0.18  0.00     16
#
# [5 rows x 30 columns]

# %%
ont_sample_df.groupby(['Age', 'Gender']).agg(lambda x: x.tolist()).reset_index()

# %%
ont_sample_df[['sample_ID','filename','path']].groupby(['sample_ID']).agg(lambda x: x.tolist()).reset_index()
# Out:
#     sample_ID                                           filename  \
# 0     GM18522  [05_17_22_R941_GM18522_1_Guppy_6.5.7_450bps_mo...
# 1     GM18570  [08_10_22_R941_GM18570_1_Guppy_6.5.7_450bps_mo...
# 2     GM18612  [06_28_22_R941_GM18612_1_Guppy_6.5.7_450bps_mo...
# 3     GM18747  [06_28_22_R941_GM18747_1_Guppy_6.5.7_450bps_mo...
# 4     GM18971  [06_28_22_R941_GM18971_1_Guppy_6.5.7_450bps_mo...
# ..        ...                                                ...
# 119   HG04184  [08_25_21_R941_HG04184_1_Guppy_6.5.7_450bps_mo...
# 120   HG04187  [08_10_21_R941_HG04187_1_Guppy_6.5.7_450bps_mo...
# 121   HG04199  [08_10_21_R941_HG04199_1_Guppy_6.5.7_450bps_mo...
# 122   HG04204  [08_10_21_R941_HG04204_1_Guppy_6.5.7_450bps_mo...
# 123   HG04228  [08_10_21_R941_HG04228_1_Guppy_6.5.7_450bps_mo...
#
#                                                   path
# 0    [s3://human-pangenomics/working/HPRC/NA18522/r...
# 1    [s3://human-pangenomics/working/HPRC/NA18570/r...
# 2    [s3://human-pangenomics/working/HPRC/NA18612/r...
# 3    [s3://human-pangenomics/working/HPRC/NA18747/r...
# 4    [s3://human-pangenomics/working/HPRC/NA18971/r...
# ..                                                 ...
# 119  [s3://human-pangenomics/working/HPRC/HG04184/r...
# 120  [s3://human-pangenomics/working/HPRC/HG04187/r...
# 121  [s3://human-pangenomics/working/HPRC/HG04199/r...
# 122  [s3://human-pangenomics/working/HPRC/HG04204/r...
# 123  [s3://human-pangenomics/working/HPRC/HG04228/r...
#
# [124 rows x 3 columns]
