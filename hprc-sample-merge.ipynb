# %%
import numpy as np
import pandas as pd
import collections

# %% [markdown]
# # ONT

# %%
ont_df = pd.read_csv('hprc_metadata_sample_files_ONT.tsv', sep='\t')

# %%
# Remove notes if all nan
if ont_df['notes'].isnull().all() == True:
    ont_df = ont_df.drop('notes', axis=1)

# %%
# TODO: Integrate with HPRC_metadata/merge_metadata.py combine_readstats.keep_columns
ont_meta_columns = ['filename',
        'sample_ID',
        'path',
        'filetype',
        'library_ID',
        'library_strategy',
        'library_source',
        'library_selection',
        'library_layout',
        'platform',
        'instrument_model',
        'design_description',
        'data_type',
        'shear_method',
        'size_selection',
        'seq_kit',
        'basecaller',
        'basecaller_version',
        'basecaller_model',
        'generator_facility',
        'generator_contact']

ont_readstat_columns = ['sample_ID', 
                        'filename',
                        'read_N50',
                        'Gb',
                        'coverage',
                        '100kb+',
                        '200kb+',
                        '300kb+',
                        '400kb+',
                        '500kb+',
                        '1Mb+',
                        'whales']

ont_df_nan_columns = ont_df.columns[ont_df.isna().any()].tolist()

# %%
ont_sample_missing_1_submitter_df = ont_df[ont_df.isnull().any(axis=1)]

# Number of ONT samples that have at least one missing submitter file missing
print(len(set(ont_df[ont_df['sample_ID'].isin(ont_sample_missing_1_submitter_df['sample_ID'].tolist())]['sample_ID'].tolist())))

# Export ONT sample files that have at least one missing submitter file missing
ont_df[ont_df['sample_ID'].isin(ont_sample_missing_1_submitter_df['sample_ID'].tolist())].reset_index(drop=True).to_csv('hprc_metadata_sample_files_missing_1_submitter_ONT.tsv', sep='\t')

for nan_column in ont_df_nan_columns:
    ont_df[nan_column] = ont_df[nan_column].ffill().tolist()
# Out:
# 14

# %%
ont_sample_meta_df = ont_df[ont_meta_columns].drop_duplicates(subset=['sample_ID'])
ont_sample_readstats_df = ont_df[ont_readstat_columns]

# %%
# Check no missing sample_ID for the sample meta and readstat subset
assert ont_df[~ont_df['sample_ID'].isin(ont_sample_meta_df['sample_ID'].tolist())].shape[0] == ont_df[~ont_df['sample_ID'].isin(ont_sample_readstats_df['sample_ID'].tolist())].shape[0] == 0

# %%
ont_sample_readstats_df = ont_sample_readstats_df.groupby('sample_ID').agg({'read_N50': 'mean',
                                                                          'coverage':'sum',
                                                                          '100kb+': 'sum',
                                                                          '200kb+': 'sum',
                                                                          '300kb+': 'sum',
                                                                          '400kb+': 'sum',
                                                                          '500kb+': 'sum',
                                                                          '1Mb+': 'sum',
                                                                          'whales': 'sum'}).reset_index()

# %%
ont_sample_df = pd.merge(ont_sample_meta_df, ont_sample_readstats_df, on='sample_ID')

# %%
assert len(set(ont_sample_df['sample_ID'].tolist())) == ont_sample_df.shape[0]

# %%
ont_sample_df.to_csv('hprc_metadata_sample_aggregate_ONT.tsv', sep='\t')

# %% [markdown]
# # HiFi

# %%
hifi_df = pd.read_csv('hprc_metadata_sample_files_HiFi.tsv', sep='\t')
hifi_df.head()
# Out:
#                         filename sample_ID  \
# 0  m54329U_200124_193652.ccs.bam   HG01891
# 1  m54329U_200127_180554.ccs.bam   HG01891
# 2  m54329U_200129_001928.ccs.bam   HG01891
# 3  m54329U_200130_064539.ccs.bam   HG01891
# 4  m54329U_200201_051510.ccs.bam   HG01123
#
#                                                 path    accession      study  \
# 0  s3://human-pangenomics/working/HPRC/HG01891/ra...  SRR13684280  SRP305758
# 1  s3://human-pangenomics/working/HPRC/HG01891/ra...  SRR13684280  SRP305758
# 2  s3://human-pangenomics/working/HPRC/HG01891/ra...  SRR13684280  SRP305758
# 3  s3://human-pangenomics/working/HPRC/HG01891/ra...  SRR13684280  SRP305758
# 4  s3://human-pangenomics/working/HPRC/HG01123/ra...  SRR13684290  SRP305758
#
#   biosample_accession  total_reads     total_bp  total_Gbp  min  ...  \
# 0        SAMN17861236      1596347  27122049640      27.12   47  ...
# 1        SAMN17861236      1755465  29883779569      29.88   46  ...
# 2        SAMN17861236      1779732  30200500419      30.20   45  ...
# 3        SAMN17861236      1636421  27919782706      27.92   46  ...
# 4        SAMN17861232      2072143  34554070679      34.55   46  ...
#
#                           design_description        data_type  shear_method  \
# 0  HiFi sequencing of 18kb fractionated gDNA  unaligned reads        g-TUBE
# 1  HiFi sequencing of 18kb fractionated gDNA  unaligned reads        g-TUBE
# 2  HiFi sequencing of 18kb fractionated gDNA  unaligned reads        g-TUBE
# 3  HiFi sequencing of 18kb fractionated gDNA  unaligned reads        g-TUBE
# 4  HiFi sequencing of 17kb fractionated gDNA  unaligned reads        g-TUBE
#
#    size_selection                        ccs_algorithm  polymerase_version  \
# 0         SageELF  ccs 4.0.0 (commit SL-release-8.0.0)                P2.0
# 1         SageELF  ccs 4.0.0 (commit SL-release-8.0.0)                P2.0
# 2         SageELF  ccs 4.0.0 (commit SL-release-8.0.0)                P2.0
# 3         SageELF  ccs 4.0.0 (commit SL-release-8.0.0)                P2.0
# 4         SageELF  ccs 4.0.0 (commit SL-release-8.0.0)                P2.0
#
#    seq_plate_chemistry_version        generator_facility generator_contact  \
# 0                         C2.0  University of Washington   kmiyamot@uw.edu
# 1                         C2.0  University of Washington   kmiyamot@uw.edu
# 2                         C2.0  University of Washington   kmiyamot@uw.edu
# 3                         C2.0  University of Washington   kmiyamot@uw.edu
# 4                         C2.0  University of Washington   kmiyamot@uw.edu
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 35 columns]

# %%
# Remove notes if all nan
if hifi_df['notes'].isnull().all() == True:
    hifi_df = hifi_df.drop('notes', axis=1)

# %%
hifi_1_submitter_metadata = ['filename', 'sample_ID', 'library_ID', 'library_strategy', 'library_source', 'library_selection', 'library_layout', 'platform', 'instrument_model', 
                    'design_description', 'data_type', 'shear_method', 'size_selection', 'ccs_algorithm', 'polymerase_version', 'seq_plate_chemistry_version', 
                    'generator_facility', 'generator_contact', 'notes']

hifi_5_readstats = ['sample_ID','filename', 'total_reads', 'total_bp', 'total_Gbp', 'min', 'max', 'mean', 'quartile_25', 'quartile_50', 'quartile_75', 'N25', 'N50', 'N75']

# %%
hifi_sample_meta_df = hifi_df[hifi_1_submitter_metadata].drop_duplicates(subset=['sample_ID']).reset_index(drop=True)

# %%
hifi_sample_missing_1_submitter_list = []
for sample in hifi_sample_meta_df['sample_ID'].tolist():
    if sum(hifi_sample_meta_df[hifi_sample_meta_df['sample_ID'].isin([sample])].isna().any()) == 0:
        pass
    else:
        hifi_sample_missing_1_submitter_df = hifi_sample_meta_df[hifi_sample_meta_df['sample_ID'].isin([sample])]
        if hifi_sample_missing_1_submitter_df.columns[hifi_sample_missing_1_submitter_df.isna().any()].tolist() == ['notes']:
            pass
        else:
            # print(sample, hifi_sample_missing_1_submitter_df.columns[hifi_sample_missing_1_submitter_df.isna().any()].tolist())
            hifi_sample_missing_1_submitter_list.append(sample)
print(len(hifi_sample_missing_1_submitter_list))
# Out:
# 20

# %%
hifi_sample_meta_df[hifi_sample_meta_df['sample_ID'].isin(hifi_sample_missing_1_submitter_list)].reset_index().to_csv('hprc_metadata_sample_files_missing_1_submitter_HiFi.tsv', sep='\t')

# %%
hifi_sample_readstats_df = hifi_df[hifi_5_readstats]
hifi_sample_readstats_df = hifi_sample_readstats_df.groupby('sample_ID').agg({'total_reads': 'sum',
                                                   'total_bp': 'sum',
                                                   'total_Gbp': 'sum',
                                                   'min': 'mean',
                                                   'max': 'mean',
                                                   'quartile_25': 'mean',
                                                   'quartile_50': 'mean',
                                                   'quartile_75': 'mean',
                                                   'N25': 'sum',
                                                   'N50': 'sum',
                                                   'N75': 'sum'}).reset_index()

# %%
hifi_sample_df = pd.merge(hifi_sample_meta_df, hifi_sample_readstats_df, on='sample_ID')

# %%
# Check that sample's with missing 1_submitter metadata are present
assert hifi_sample_df[hifi_sample_df['sample_ID'].isin(hifi_sample_missing_1_submitter_list)].shape[0] == len(hifi_sample_missing_1_submitter_list)

# %%
hifi_sample_df.to_csv('hprc_metadata_sample_aggregate_HiFi.tsv', sep='\t')

# %% [markdown]
# # Deep Consensus

# %%
dc_df = pd.read_csv('hprc_metadata_sample_files_DEEPCONSENSUS.tsv', sep='\t')
dc_df.head()
# Out:
#                                         filename sample_ID  \
# 0  HG00099.m54329U_220825_174247.dc.q20.fastq.gz   HG00099
# 1  HG00099.m54329U_220827_143814.dc.q20.fastq.gz   HG00099
# 2  HG00099.m54329U_220829_095708.dc.q20.fastq.gz   HG00099
# 3   HG00140.m64043_220728_173215.dc.q20.fastq.gz   HG00140
# 4   HG00140.m64136_220715_182717.dc.q20.fastq.gz   HG00140
#
#                                                 path    accession      study  \
# 0  s3://human-pangenomics/working/HPRC/HG00099/ra...  SRR26545347  SRP305758
# 1  s3://human-pangenomics/working/HPRC/HG00099/ra...  SRR26545347  SRP305758
# 2  s3://human-pangenomics/working/HPRC/HG00099/ra...  SRR26545347  SRP305758
# 3  s3://human-pangenomics/working/HPRC/HG00140/ra...  SRR26545346  SRP305758
# 4  s3://human-pangenomics/working/HPRC/HG00140/ra...  SRR26545346  SRP305758
#
#   biosample_accession  total_reads     total_bp  total_Gbp  min  ...  \
# 0        SAMN33758778      2687625  56102007798      56.10  107  ...
# 1        SAMN33758778      2643186  52918724515      52.92  345  ...
# 2        SAMN33758778      2866917  57539149577      57.54  138  ...
# 3        SAMN33621941       572695  11345594738      11.35  117  ...
# 4        SAMN33621941      1674999  36918329655      36.92  400  ...
#
#                                   design_description        data_type  \
# 0  HiFi sequencing of 20kb fractionated gDNA reba...  unaligned reads
# 1  HiFi sequencing of 20kb fractionated gDNA reba...  unaligned reads
# 2  HiFi sequencing of 20kb fractionated gDNA reba...  unaligned reads
# 3  HiFi sequencing of 20kb fractionated gDNA reba...  unaligned reads
# 4  HiFi sequencing of 20kb fractionated gDNA reba...  unaligned reads
#
#    shear_method  size_selection  DeepConsensus_version  polymerase_version  \
# 0  Megaruptor 3        PippinHT                    1.2                  P2
# 1  Megaruptor 3        PippinHT                    1.2                  P2
# 2  Megaruptor 3        PippinHT                    1.2                  P2
# 3  Megaruptor 3        PippinHT                    1.2                  P2
# 4  Megaruptor 3        PippinHT                    1.2                  P2
#
#    seq_plate_chemistry_version        generator_facility generator_contact  \
# 0                           C2  University of Washington   kmiyamot@uw.edu
# 1                           C2  University of Washington   kmiyamot@uw.edu
# 2                           C2  University of Washington   kmiyamot@uw.edu
# 3                           C2  University of Washington   kmiyamot@uw.edu
# 4                           C2  University of Washington   kmiyamot@uw.edu
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 35 columns]

# %%
# Remove notes if all nan
if dc_df['notes'].isnull().all() == True:
    dc_df = dc_df.drop('notes', axis=1)

# %%
required_deepconsensus_submitter_columns = ['filename', 'sample_ID', 'library_ID', 'library_strategy', 'library_source', 
                                            'library_selection', 'library_layout', 'platform', 'instrument_model', 'design_description', 
                                            'data_type', 'shear_method', 'size_selection', 
                                            'DeepConsensus_version', 'polymerase_version', 
                                            'seq_plate_chemistry_version', 'generator_facility', 
                                            'generator_contact']

required_deepconsensus_readstats_columns = ['sample_ID', 'filename', 'total_reads', 'total_bp', 'total_Gbp', 'min', 'max', 'mean', 'quartile_25', 'quartile_50', 'quartile_75', 'N25', 'N50', 'N75']

# %%
dc_sample_meta_df = dc_df[required_deepconsensus_submitter_columns].drop_duplicates(subset=['sample_ID']).reset_index(drop=True)

# %%
dc_sample_missing_1_submitter_list = []
for sample in dc_sample_meta_df['sample_ID'].tolist():
    if sum(dc_sample_meta_df[dc_sample_meta_df['sample_ID'].isin([sample])].isna().any()) == 0:
        pass
    else:
        dc_sample_missing_1_submitter_df = dc_sample_meta_df[dc_sample_meta_df['sample_ID'].isin([sample])]
        if dc_sample_missing_1_submitter_df.columns[dc_sample_missing_1_submitter_df.isna().any()].tolist() == ['notes']:
            pass
        else:
            # print(sample, hifi_sample_missing_1_submitter_df.columns[hifi_sample_missing_1_submitter_df.isna().any()].tolist())
            dc_sample_missing_1_submitter_list.append(sample)
print(len(dc_sample_missing_1_submitter_list))
# Out:
# 0

# %%
# Check all dc sample 5_readstats data is present
assert sum(dc_df[required_deepconsensus_readstats_columns].isna().any()) == 0

# %%
dc_sample_readstats_df = dc_df[required_deepconsensus_readstats_columns]

dc_sample_readstats_df = dc_sample_readstats_df.groupby('sample_ID').agg({'total_reads': 'sum',
                                               'total_bp': 'sum',
                                               'total_Gbp': 'sum',
                                               'min': 'mean',
                                               'max': 'mean',
                                               'quartile_25': 'mean',
                                               'quartile_50': 'mean',
                                               'quartile_75': 'mean',
                                               'N25': 'sum',
                                               'N50': 'sum',
                                               'N75': 'sum'}).reset_index()

# %%
dc_sample_df = pd.merge(dc_sample_meta_df, dc_sample_readstats_df, on='sample_ID')

# %%
dc_sample_df.to_csv('hprc_metadata_sample_aggregate_DEEPCONSENSUS.tsv', sep='\t')
# Out:
#                                          filename sample_ID  \
# 0   HG00099.m54329U_220825_174247.dc.q20.fastq.gz   HG00099
# 1    HG00140.m64043_220728_173215.dc.q20.fastq.gz   HG00140
# 2   HG00280.m54329U_220901_221341.dc.q20.fastq.gz   HG00280
# 3    HG00323.m64043_220728_173215.dc.q20.fastq.gz   HG00323
# 4    HG00408.m64136_211111_194404.dc.q20.fastq.gz   HG00408
# 5   HG00558.m54329U_220107_233847.dc.q20.fastq.gz   HG00558
# 6    HG00597.m64043_211210_180342.dc.q20.fastq.gz   HG00597
# 7   HG00639.m54329U_211222_104516.dc.q20.fastq.gz   HG00639
# 8   HG01074.m54329U_211110_112322.dc.q20.fastq.gz   HG01074
# 9   HG01081.m54329U_211223_214216.dc.q20.fastq.gz   HG01081
# 10   HG01192.m64043_211124_192057.dc.q20.fastq.gz   HG01192
# 11   HG01261.m64043_211222_184851.dc.q20.fastq.gz   HG01261
# 12   HG01975.m64043_211113_003158.dc.q20.fastq.gz   HG01975
# 13   HG02015.m64043_210901_164337.dc.q20.fastq.gz   HG02015
# 14   HG02040.m64076_220908_204946.dc.q20.fastq.gz   HG02040
# 15   HG02056.m64043_220114_181052.dc.q20.fastq.gz   HG02056
# 16   HG02129.m64136_220422_181133.dc.q20.fastq.gz   HG02129
# 17   HG02155.m64043_220728_173215.dc.q20.fastq.gz   HG02155
# 18   HG02165.m64076_220902_143723.dc.q20.fastq.gz   HG02165
# 19   HG02258.m64043_211217_180919.dc.q20.fastq.gz   HG02258
# 20   HG02273.m64043_220429_171542.dc.q20.fastq.gz   HG02273
# 21   HG02451.m64076_211109_232223.dc.q20.fastq.gz   HG02451
# 22  HG02735.m54329U_211109_002533.dc.q20.fastq.gz   HG02735
# 23  HG02922.m54329U_220816_182601.dc.q20.fastq.gz   HG02922
# 24   HG02965.m64043_220715_182700.dc.q20.fastq.gz   HG02965
# 25   HG02976.m64043_220617_195135.dc.q20.fastq.gz   HG02976
# 26  HG03017.m54329U_211225_070909.dc.q20.fastq.gz   HG03017
# 27  HG03041.m54329U_211214_012740.dc.q20.fastq.gz   HG03041
# 28   HG03130.m64076_220513_215716.dc.q20.fastq.gz   HG03130
# 29  HG03139.m54329U_220519_225150.dc.q20.fastq.gz   HG03139
# 30   HG03195.m64043_220726_203720.dc.q20.fastq.gz   HG03195
# 31   HG03209.m64076_220520_234906.dc.q20.fastq.gz   HG03209
# 32   HG03225.m64043_220518_120044.dc.q20.fastq.gz   HG03225
# 33  HG03239.m54329U_220105_011819.dc.q20.fastq.gz   HG03239
# 34  HG03704.m54329U_211105_213234.dc.q20.fastq.gz   HG03704
# 35   HG03834.m64043_220107_191226.dc.q20.fastq.gz   HG03834
# 36   HG06807.m64043_211118_185250.dc.q20.fastq.gz   HG06807
# 37  NA18522.m54329U_220604_002013.dc.q20.fastq.gz   NA18522
# 38   NA18612.m64043_220708_205637.dc.q20.fastq.gz   NA18612
# 39  NA18747.m54329U_220823_191353.dc.q20.fastq.gz   NA18747
# 40   NA18971.m64043_220701_181144.dc.q20.fastq.gz   NA18971
# 41  NA18983.m64457e_220902_165459.dc.q20.fastq.gz   NA18983
# 42  NA19043.m54329U_220916_162216.dc.q20.fastq.gz   NA19043
# 43  NA20752.m64457e_220827_152226.dc.q20.fastq.gz   NA20752
# 44   NA20805.m64136_220726_203708.dc.q20.fastq.gz   NA20805
# 45   NA20905.m64076_220914_214248.dc.q20.fastq.gz   NA20905
#
#                        library_ID library_strategy library_source  \
# 0               PG00099_1.HFSS_dc              WGS        GENOMIC
# 1                 HG00140_lib1_dc              WGS        GENOMIC
# 2                 PG00280.HFSS_dc              WGS        GENOMIC
# 3                 HG00323_lib1_dc              WGS        GENOMIC
# 4                 HG00408_lib1_dc              WGS        GENOMIC
# 5                 HG00558.HFSS_dc              WGS        GENOMIC
# 6                 HG00597_lib1_dc              WGS        GENOMIC
# 7                 HG00639.HFSS_dc              WGS        GENOMIC
# 8             HG01074_SRE.HFSS_dc              WGS        GENOMIC
# 9                 HG01081.HFSS_dc              WGS        GENOMIC
# 10                HG01192_lib1_dc              WGS        GENOMIC
# 11                HG01261_lib1_dc              WGS        GENOMIC
# 12                HG01975_lib1_dc              WGS        GENOMIC
# 13                HG02015_lib1_dc              WGS        GENOMIC
# 14               HG02040.HFSS2_dc              WGS        GENOMIC
# 15                HG02056_lib1_dc              WGS        GENOMIC
# 16                HG02129_lib1_dc              WGS        GENOMIC
# 17                HG02155_lib1_dc              WGS        GENOMIC
# 18               PG02165.HFSS2_dc              WGS        GENOMIC
# 19                HG02258_lib1_dc              WGS        GENOMIC
# 20                HG02273_lib1_dc              WGS        GENOMIC
# 21            HG02451_SRE.HFSS_dc              WGS        GENOMIC
# 22            HG02735_SRE.HFSS_dc              WGS        GENOMIC
# 23                PG02922.HFSS_dc              WGS        GENOMIC
# 24                HG02965_lib1_dc              WGS        GENOMIC
# 25                HG02976_lib1_dc              WGS        GENOMIC
# 26                HG03017.HFSS_dc              WGS        GENOMIC
# 27                HG03041.HFSS_dc              WGS        GENOMIC
# 28                HG03130.HFSS_dc              WGS        GENOMIC
# 29                HG03139.HFSS_dc              WGS        GENOMIC
# 30                HG03195_lib1_dc              WGS        GENOMIC
# 31                HG03209.HFSS_dc              WGS        GENOMIC
# 32                HG03225_lib1_dc              WGS        GENOMIC
# 33                HG03239.HFSS_dc              WGS        GENOMIC
# 34            HG03704_SRE.HFSS_dc              WGS        GENOMIC
# 35                HG03834_lib1_dc              WGS        GENOMIC
# 36  MGISTL_PAN027_HG06807_lib1_dc              WGS        GENOMIC
# 37                NA18522.HFSS_dc              WGS        GENOMIC
# 38                NA18612_lib1_dc              WGS        GENOMIC
# 39              PG18747_1.HFSS_dc              WGS        GENOMIC
# 40                NA18971_lib1_dc              WGS        GENOMIC
# 41               PG18983.HFSS2_dc              WGS        GENOMIC
# 42                PG19043.HFSS_dc              WGS        GENOMIC
# 43                PG20752.HFSS_dc              WGS        GENOMIC
# 44                NA20805_lib1_dc              WGS        GENOMIC
# 45                PG20905.HFSS_dc              WGS        GENOMIC
#
#      library_selection library_layout     platform  instrument_model  \
# 0   size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 1   size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 2   size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 3   size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 4   size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 5   size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 6   size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 7   size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 8   size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 9   size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 10  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 11  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 12  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 13  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 14  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 15  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 16  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 17  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 18  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 19  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 20  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 21  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 22  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 23  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 24  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 25  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 26  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 27  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 28  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 29  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 30  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 31  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 32  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 33  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 34  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 35  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 36  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 37  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 38  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 39  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 40  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 41  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 42  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 43  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 44  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
# 45  size fractionation         single  PACBIO_SMRT  PacBio Sequel II
#
#                                    design_description  ...      total_bp  \
# 0   HiFi sequencing of 20kb fractionated gDNA reba...  ...  166559881890
# 1   HiFi sequencing of 20kb fractionated gDNA reba...  ...  126611334877
# 2   HiFi sequencing of 20kb fractionated gDNA reba...  ...  151564344052
# 3   HiFi sequencing of 20kb fractionated gDNA reba...  ...  120027730827
# 4   HiFi sequencing of 20kb fractionated gDNA reba...  ...  134450022475
# 5   HiFi sequencing of 20kb fractionated gDNA reba...  ...  125476773513
# 6   HiFi sequencing of 20kb fractionated gDNA reba...  ...  136188293000
# 7   HiFi sequencing of 20kb fractionated gDNA reba...  ...  129823813816
# 8   HiFi sequencing of 20kb fractionated gDNA reba...  ...  143703615375
# 9   HiFi sequencing of 20kb fractionated gDNA reba...  ...  131091771689
# 10  HiFi sequencing of 20kb fractionated gDNA reba...  ...  137542735446
# 11  HiFi sequencing of 20kb fractionated gDNA reba...  ...  132770447728
# 12  HiFi sequencing of 20kb fractionated gDNA reba...  ...  121417620190
# 13  HiFi sequencing of 20kb fractionated gDNA reba...  ...  125875719290
# 14  HiFi sequencing of 20kb fractionated gDNA reba...  ...  153044049343
# 15  HiFi sequencing of 20kb fractionated gDNA reba...  ...  138625934903
# 16  HiFi sequencing of 20kb fractionated gDNA reba...  ...  126751685854
# 17  HiFi sequencing of 20kb fractionated gDNA reba...  ...  126129002873
# 18  HiFi sequencing of 20kb fractionated gDNA reba...  ...  157437648340
# 19  HiFi sequencing of 20kb fractionated gDNA reba...  ...  133053239389
# 20  HiFi sequencing of 20kb fractionated gDNA reba...  ...  137880480728
# 21  HiFi sequencing of 20kb fractionated gDNA reba...  ...  146928480042
# 22  HiFi sequencing of 20kb fractionated gDNA reba...  ...  128966341210
# 23  HiFi sequencing of 20kb fractionated gDNA reba...  ...  177615501715
# 24  HiFi sequencing of 20kb fractionated gDNA reba...  ...  132920025321
# 25  HiFi sequencing of 20kb fractionated gDNA reba...  ...  124726568925
# 26  HiFi sequencing of 20kb fractionated gDNA reba...  ...  138503809328
# 27  HiFi sequencing of 20kb fractionated gDNA reba...  ...  132165167295
